# %%
import matplotlib.pyplot as plt

values = [10, 15, 20, 15, 20]

plt.hist(values, bins=5, color='blue', edgecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt

values = [10, 15, 20, 15, 20]

plt.hist(values, bins=5, color='red', edgecolor='green')
plt.show()

# %%
import matplotlib.pyplot as plt

values = [10, 15, 20, 15, 20]

plt.hist(values,  color='purple', edgecolor='orange')
plt.show()
