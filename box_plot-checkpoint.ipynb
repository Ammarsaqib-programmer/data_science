# %%
import seaborn as sns
import matplotlib.pyplot as plt  
titanic = sns.load_dataset("titanic")
sns.catplot(x="class", y="fare", hue="sex", kind="bar", data=titanic)

plt.show()

# %%
#horizontak
import seaborn as sns
import matplotlib.pyplot as plt  

titanic = sns.load_dataset("titanic")

sns.catplot(y="class", x="fare", hue="sex", kind="bar", data=titanic)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt  

titanic = sns.load_dataset("titanic")

sns.barplot(
    y="class", x="fare", data=titanic,
    linewidth=2, edgecolor="black",
    facecolor=(1,1,1,0)
)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt  

titanic = sns.load_dataset("titanic")

sns.barplot(
     x="fare",y="class", data=titanic,
    linewidth=2, edgecolor="black",
    facecolor="brown"
)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt  

titanic = sns.load_dataset("titanic")

sns.barplot(
     x="fare",y="class", data=titanic,
    linewidth=10, edgecolor="teal",
    palette="pastel"
)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9164\3568347389.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import seaborn as sns
import matplotlib.pyplot as plt  

titanic = sns.load_dataset("titanic")

sns.barplot(
     x="fare",y="class", data=titanic,
    linewidth=10, edgecolor="1",
    palette="pastel"
)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9164\4289286034.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import seaborn as sns
import matplotlib.pyplot as plt  

titanic = sns.load_dataset("titanic")

sns.barplot(
     x="fare",y="class", data=titanic,
    linewidth=10, edgecolor="0",
    palette="pastel"
)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9164\180038951.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import seaborn as sns
import matplotlib.pyplot as plt  

titanic = sns.load_dataset("titanic")

sns.barplot(
     x="class",y="fare", data=titanic,
    linewidth=10, edgecolor="0",
    palette="pastel"
)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9164\2261039677.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import seaborn
seaborn.set(style="whitegrid")
fmri = sns.load_dataset("fmri")
seaborn.boxplot(x="timepoint", y="signal",data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import seaborn
seaborn.set(style="whitegrid")
kashti = sns.load_dataset("titanic")
seaborn.boxplot(x="class", y="fare",data=kashti)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips
sns.boxplot(x="day",y="tip", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips
sns.boxplot(x="day",y="tip", data=tips, saturation=5 )
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
seaborn.boxplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
seaborn.boxplot(y=tips['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips
sns.boxplot(x="tip",y="day", data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips
sns.boxplot(x="tip",y="day",hue="smoker", data=tips, dodge=True)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn
seaborn.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips
sns.boxplot(x="tip",y="day",hue="smoker", data=tips, dodge=False)
# Out:
# <Axes: xlabel='tip', ylabel='day'>
